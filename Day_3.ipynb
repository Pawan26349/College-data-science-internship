# %%
import pandas as pd

# %%
df = pd.read_csv('Pokemon.csv')

df.shape
# Out:
# (800, 13)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.drop(columns=["#"])
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
plt.style.use('fivethirtyeight')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Column operations

# %%
df.columns = df.columns.str.upper().str.replace('_','')
df
# Out:
#        #                   NAME   TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df[df['LEGENDARY']==True].head()
# Out:
#        #                 NAME    TYPE 1    TYPE 2  TOTAL   HP  ATTACK  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      DEFENSE  SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
df = df.set_index('NAME')
df
# Out:
#                          #   TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# NAME
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# ...

# %%
df.index = df.index.str.replace(".*(?=Mega)","")
df.head()
# Out:
# C:\Users\PAWAN\AppData\Local\Temp\ipykernel_16524\3867640417.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace(".*(?=Mega)","")
#                # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur      1  Grass  Poison    318  45      49       49       65       65
# Ivysaur        2  Grass  Poison    405  60      62       63       80       80
# Venusaur       3  Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  3  Grass  Poison    625  80     100      123      122      120
# Charmander     4   Fire     NaN    309  39      52       43       60       50
#
#                SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur         45           1      False
# Ivysaur           60           1      False
# Venusaur          80           1      False
# Mega Venusaur     80           1      False
# Charmander        65           1      False

# %%
df
# Out:
#                        #   TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# NAME
# Bulbasaur              1    Grass  Poison    318  45      49       49
# Ivysaur                2    Grass  Poison    405  60      62       63
# Venusaur               3    Grass  Poison    525  80      82       83
# Mega Venusaur          3    Grass  Poison    625  80     100      123
# Charmander             4     Fire     NaN    309  39      52       43
# ...                  ...      ...     ...    ...  ..     ...      ...
# Diancie              719     Rock   Fairy    600  50     100      150
# Mega Diancie         719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined  720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound   720  Psychic    Dark    680  80     160       60
# Volcanion            721     Fire   Water    600  80     110      120
#
#                      SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# ...

# %%
df = df.drop(['#'],axis=1)
df
# Out:
#                       TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# Mega Venusaur          Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
# ...                      ...     ...    ...  ..     ...      ...      ...
# Diancie                 Rock   Fairy    600  50     100      150      100
# Mega Diancie            Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined  Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound   Psychic    Dark    680  80     160       60      170
# Volcanion               Fire   Water    600  80     110      120      130
#
#                      SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      800 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       800 non-null    int64
#  3   HP          800 non-null    int64
#  4   ATTACK      800 non-null    int64
#  5   DEFENSE     800 non-null    int64
#  6   SP. ATK     800 non-null    int64
#  7   SP. DEF     800 non-null    int64
#  8   SPEED       800 non-null    int64
#  9   GENERATION  800 non-null    int64
#  10  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 69.5+ KB

# %% [markdown]
# filtering pokemons using logical operators

# %%
print(df[((df['TYPE 1']=='Water') | (df['TYPE 1']=='Dragon')) & ((df['TYPE 2']=='Dragon') | (df['TYPE 2']=='Dragon'))])
# Out:
#         TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  SPEED  \
# NAME
# Kingdra  Water  Dragon    540  75      95       95       95       95     85
# Palkia   Water  Dragon    680  90     120      100      150      120    100
#
#          GENERATION  LEGENDARY
# NAME
# Kingdra           2      False
# Palkia            4       True

# %%
print("MAx HP : ",df['ATTACK'].argmax())
# Out:
# MAx HP :  163

# %%
print(df[df['ATTACK']==190])

# print(df.)
# Out:
#                 TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Mega Mewtwo X  Psychic  Fighting    780  106     190      100      154
#
#                SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Mega Mewtwo X      100    130           1       True

# %%
print("max_defense ",(df['DEFENSE']).idxmax())
# Out:
# max_defense  Mega Steelix

# %%
# df.sort_values("Total",ascending=False).head()

# %%
df2 = df.drop(['GENERATION','TOTAL'],axis=1)
df2
# Out:
#                       TYPE 1  TYPE 2  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur              Grass  Poison  45      49       49       65       65
# Ivysaur                Grass  Poison  60      62       63       80       80
# Venusaur               Grass  Poison  80      82       83      100      100
# Mega Venusaur          Grass  Poison  80     100      123      122      120
# Charmander              Fire     NaN  39      52       43       60       50
# ...                      ...     ...  ..     ...      ...      ...      ...
# Diancie                 Rock   Fairy  50     100      150      100      150
# Mega Diancie            Rock   Fairy  50     160      110      160      110
# HoopaHoopa Confined  Psychic   Ghost  80     110       60      150      130
# HoopaHoopa Unbound   Psychic    Dark  80     160       60      170      130
# Volcanion               Fire   Water  80     110      120      130       90
#
#                      SPEED  LEGENDARY
# NAME
# ...

# %%
import numpy as np
data = np.random.randint(0,10,size=(5,5))

plt.imshow(data,cmap='hot')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %% [markdown]
# Data Cleaning

# %%
df.info()
# data_cleaned = data.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      800 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       800 non-null    int64
#  3   HP          800 non-null    int64
#  4   ATTACK      800 non-null    int64
#  5   DEFENSE     800 non-null    int64
#  6   SP. ATK     800 non-null    int64
#  7   SP. DEF     800 non-null    int64
#  8   SPEED       800 non-null    int64
#  9   GENERATION  800 non-null    int64
#  10  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 101.8+ KB

# %%
data_cleaned = df.dropna()
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      414 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       414 non-null    int64
#  3   HP          414 non-null    int64
#  4   ATTACK      414 non-null    int64
#  5   DEFENSE     414 non-null    int64
#  6   SP. ATK     414 non-null    int64
#  7   SP. DEF     414 non-null    int64
#  8   SPEED       414 non-null    int64
#  9   GENERATION  414 non-null    int64
#  10  LEGENDARY   414 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 36.0+ KB

# %%
data_cleaned = df
data_cleaned = df.fillna(data.mean())
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      800 non-null    object
#  1   TYPE 2      800 non-null    object
#  2   TOTAL       800 non-null    int64
#  3   HP          800 non-null    int64
#  4   ATTACK      800 non-null    int64
#  5   DEFENSE     800 non-null    int64
#  6   SP. ATK     800 non-null    int64
#  7   SP. DEF     800 non-null    int64
#  8   SPEED       800 non-null    int64
#  9   GENERATION  800 non-null    int64
#  10  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 101.8+ KB

# %%
data_cleaned = df.drop_duplicates()
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 797 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      797 non-null    object
#  1   TYPE 2      413 non-null    object
#  2   TOTAL       797 non-null    int64
#  3   HP          797 non-null    int64
#  4   ATTACK      797 non-null    int64
#  5   DEFENSE     797 non-null    int64
#  6   SP. ATK     797 non-null    int64
#  7   SP. DEF     797 non-null    int64
#  8   SPEED       797 non-null    int64
#  9   GENERATION  797 non-null    int64
#  10  LEGENDARY   797 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 69.3+ KB

# %%
data_with_dropped_columns = df.drop(columns=['TYPE 1','TYPE 2'])
data_with_dropped_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TOTAL       800 non-null    int64
#  1   HP          800 non-null    int64
#  2   ATTACK      800 non-null    int64
#  3   DEFENSE     800 non-null    int64
#  4   SP. ATK     800 non-null    int64
#  5   SP. DEF     800 non-null    int64
#  6   SPEED       800 non-null    int64
#  7   GENERATION  800 non-null    int64
#  8   LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(8)
# memory usage: 89.3+ KB

# %%
data_cleaned['Transformed Column'] = np.log(data_cleaned['TOTAL'])
data_cleaned
# Out:
# C:\Users\PAWAN\AppData\Local\Temp\ipykernel_16524\901229363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Transformed Column'] = np.log(data_cleaned['TOTAL'])
#                       TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# Mega Venusaur          Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
# ...                      ...     ...    ...  ..     ...      ...      ...
# ...

# %%
data_encoded = pd.get_dummies(data_cleaned,columns=['TYPE 1'])
data_encoded
# Out:
#                      TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur            Poison    318  45      49       49       65       65
# Ivysaur              Poison    405  60      62       63       80       80
# Venusaur             Poison    525  80      82       83      100      100
# Mega Venusaur        Poison    625  80     100      123      122      120
# Charmander              NaN    309  39      52       43       60       50
# ...                     ...    ...  ..     ...      ...      ...      ...
# Diancie               Fairy    600  50     100      150      100      150
# Mega Diancie          Fairy    700  50     160      110      160      110
# HoopaHoopa Confined   Ghost    600  80     110       60      150      130
# HoopaHoopa Unbound     Dark    680  80     160       60      170      130
# Volcanion             Water    600  80     110      120      130       90
#
#                      SPEED  GENERATION  LEGENDARY  ...  TYPE 1_Ghost  \
# ...
